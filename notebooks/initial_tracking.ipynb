# %%
import pandas as pd
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import Lasso
from sklearn.metrics import root_mean_squared_error

def read_dataframe(path):
    df = pd.read_parquet(path)
    df["duration"] = (df.lpep_dropoff_datetime - df.lpep_pickup_datetime).dt.total_seconds() / 60
    df = df[(df.duration >= 1) & (df.duration <= 60)]
    df[["PULocationID", "DOLocationID"]] = df[["PULocationID", "DOLocationID"]].astype(str)
    return df

df_train = read_dataframe("../data/green_tripdata_2025-01.parquet")
df_val = read_dataframe("../data/green_tripdata_2025-02.parquet")

df_train["PU_DO"] = df_train["PULocationID"] + "_" + df_train["DOLocationID"]
df_val["PU_DO"] = df_val["PULocationID"] + "_" + df_val["DOLocationID"]

categorical = ["PU_DO"]
numerical = ["trip_distance"]

dv = DictVectorizer()
X_train = dv.fit_transform(df_train[categorical + numerical].to_dict(orient="records"))
X_val = dv.transform(df_val[categorical + numerical].to_dict(orient="records"))

y_train = df_train["duration"].values
y_val = df_val["duration"].values

# %%
df_train
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0             2  2025-01-01 00:03:01   2025-01-01 00:17:12                  N
# 1             2  2025-01-01 00:19:59   2025-01-01 00:25:52                  N
# 2             2  2025-01-01 00:05:29   2025-01-01 00:07:21                  N
# 3             2  2025-01-01 00:52:24   2025-01-01 01:07:52                  N
# 4             2  2025-01-01 00:25:05   2025-01-01 01:01:10                  N
# ...         ...                  ...                   ...                ...
# 48321         2  2025-01-31 19:36:00   2025-01-31 20:05:00               None
# 48322         2  2025-01-31 20:33:00   2025-01-31 20:41:00               None
# 48323         2  2025-01-31 21:09:00   2025-01-31 21:30:00               None
# 48324         2  2025-01-31 22:22:00   2025-01-31 22:25:00               None
# 48325         2  2025-01-31 22:15:00   2025-01-31 22:22:00               None
#
#        RatecodeID PULocationID DOLocationID  passenger_count  trip_distance  \
# 0             1.0           75          235              1.0           5.93
# 1             1.0          166           75              1.0           1.32
# 2             5.0          171           73              1.0           0.41
# 3             1.0           74          223              1.0           4.12
# 4             1.0           66          158              1.0           4.71
# ...           ...          ...          ...              ...            ...
# 48321         NaN          179          132              NaN          13.99
# 48322         NaN          166           75              NaN           1.51
# 48323         NaN           41           42              NaN           2.90
# 48324         NaN           75           43              NaN           0.34
# 48325         NaN           42          194              NaN           1.37
#
#        fare_amount  ...  tolls_amount  ehail_fee  improvement_surcharge  \
# 0            24.70  ...          0.00        NaN                    1.0
# 1             8.60  ...          0.00        NaN                    1.0
# 2            25.55  ...          0.00        NaN                    1.0
# 3            21.20  ...          6.94        NaN                    1.0
# 4            33.80  ...          0.00        NaN                    1.0
# ...            ...  ...           ...        ...                    ...
# 48321        55.61  ...          0.00        NaN                    1.0
# 48322        13.58  ...          0.00        NaN                    1.0
# 48323        30.89  ...          0.00        NaN                    1.0
# 48324        14.78  ...          0.00        NaN                    1.0
# 48325        66.67  ...          6.94        NaN                    1.0
#
#        total_amount  payment_type  trip_type  congestion_surcharge  \
# 0             34.00           1.0        1.0                  0.00
# 1             11.10           2.0        1.0                  0.00
# 2             26.55           2.0        2.0                  0.00
# 3             36.77           1.0        1.0                  0.00
# 4             46.86           1.0        1.0                  2.75
# ...             ...           ...        ...                   ...
# 48321         68.53           NaN        NaN                   NaN
# 48322         17.34           NaN        NaN                   NaN
# 48323         32.39           NaN        NaN                   NaN
# 48324         18.72           NaN        NaN                   NaN
# 48325         85.11           NaN        NaN                   NaN
#
#        cbd_congestion_fee   duration    PU_DO
# 0                     0.0  14.183333   75_235
# 1                     0.0   5.883333   166_75
# 2                     0.0   1.866667   171_73
# 3                     0.0  15.466667   74_223
# 4                     0.0  36.083333   66_158
# ...                   ...        ...      ...
# 48321                 NaN  29.000000  179_132
# 48322                 NaN   8.000000   166_75
# 48323                 NaN  21.000000    41_42
# 48324                 NaN   3.000000    75_43
# 48325                 NaN   7.000000   42_194
#
# [46307 rows x 23 columns]

# %%
import mlflow

mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("class-nyc-taxi-experiment")

with mlflow.start_run(run_name="lasso_alpha_0.1"):
    alpha = 0.1
    mlflow.log_param("alpha", alpha)

    model = Lasso(alpha=alpha)
    model.fit(X_train, y_train)

    y_pred = model.predict(X_val)
    rmse = root_mean_squared_error(y_val, y_pred)

    mlflow.log_metric("rmse", rmse)
    mlflow.sklearn.log_model(model, "model")

    print(f"✅ Run finalizado. RMSE = {rmse:.4f}")
# Out:
# 2025/10/28 19:06:25 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2025/10/28 19:06:25 INFO mlflow.store.db.utils: Updating database tables
# 2025-10-28 19:06:25 INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# 2025-10-28 19:06:25 INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# 2025-10-28 19:06:26 INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# 2025-10-28 19:06:26 INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# 2025/10/28 19:06:26 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/10/28 19:06:29 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# ✅ Run finalizado. RMSE = 8.9926

# %%
from sklearn.ensemble import GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.svm import LinearSVR

# %%
import mlflow

# %%
mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment(experiment_name="nyc-taxi-model-registry-example")
# Out:
# <Experiment: artifact_location=('file:c:/Users/canal/Documents/Semestre 7/Proyecto de Ciencia de '
#  'Datos/nyc-predictions/nyc-taxi-predictions-2025-2/notebooks/mlruns/2'), creation_time=1761697587965, experiment_id='2', last_update_time=1761697587965, lifecycle_stage='active', name='nyc-taxi-model-registry-example', tags={}>

# %%
mlflow.sklearn.autolog()

# %%
import pickle

# %%
training_dataset = mlflow.data.from_numpy(X_train.data, targets=y_train, name="green_tripdata_2025-01")
validation_dataset = mlflow.data.from_numpy(X_val.data, targets=y_val, name="green_tripdata_2025-02")

# %%
models = [
    
    {"model": GradientBoostingRegressor,
     "params": {"n_estimators": 100, "learning_rate": 0.3, "max_depth": 25, "random_state": 42},
     },
    
    {"model": ExtraTreesRegressor,
     "params": {"n_estimators": 100, "max_depth": 15, "random_state": 42},
     },
    
    {"model": LinearSVR,
     "params": {"C": 1.0, "epsilon": 0}, 
     },

]

# %%
with mlflow.start_run(run_name="Nested Runs"):
    for model in models:
        
        model_class = model["model"]
        model_name = model_class.__name__
        params = model["params"]
        
        with mlflow.start_run(run_name=model_name,nested=True):
            
            ml_model = model_class(**params)
           
            ml_model.fit(X_train, y_train)
    
            y_pred = ml_model.predict(X_val)
            
            rmse = root_mean_squared_error(y_val, y_pred)
            mlflow.log_metric("rmse", rmse)
            
            #!mkdir models
            with open("../models/preprocessor.b", "wb") as f_out:
                pickle.dump(dv, f_out)
                
            mlflow.log_artifact("../models/preprocessor.b", artifact_path="preprocessor")
# Out:
# c:\Users\canal\miniconda3\Lib\site-packages\sklearn\svm\_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %%
from sklearn.ensemble import RandomForestRegressor


with mlflow.start_run(run_name="RandomForestRegressor"):
    ml_model = RandomForestRegressor(
        n_estimators=100,
        max_depth=15,
        random_state=42
    )
    
    ml_model.fit(X_train, y_train)
    
    mlflow.sklearn.log_model(
        sk_model=model, 
        artifact_path="model",
        registered_model_name="nyc-taxi-model"
    )
    
    y_pred = ml_model.predict(X_val)
    
    rmse = root_mean_squared_error(y_val, y_pred)
    mlflow.log_metric("rmse", rmse)
    
    # !mkdir models
    with open("../models/preprocessor.b", "wb") as f_out:
        pickle.dump(dv, f_out)
        
    mlflow.log_artifact("../models/preprocessor.b", artifact_path="preprocessor")
# Out:
# 2025/10/28 19:07:41 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/10/28 19:07:41 WARNING mlflow.sklearn: Model was missing function: predict. Not logging python_function flavor!
# 2025/10/28 19:07:44 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/10/28 19:07:44 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2025/10/28 19:07:44 INFO mlflow.store.db.utils: Updating database tables
# 2025-10-28 19:07:44 INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# 2025-10-28 19:07:44 INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# Registered model 'nyc-taxi-model' already exists. Creating a new version of this model...
# Created version '4' of model 'nyc-taxi-model'.

# %%
run_id = input("b74ba998fb4348adb5cde521b6063829")
run_uri = f"runs:/{run_id}/model"

result = mlflow.register_model(
    model_uri=run_uri,
    name="nyc-taxi-model"
)
# Out:
# Registered model 'nyc-taxi-model' already exists. Creating a new version of this model...
# 2025/10/28 19:07:57 WARNING mlflow.tracking._model_registry.fluent: Run with id b74ba998fb4348adb5cde521b6063829 has no artifacts at artifact path 'model', registering model based on models:/m-6a93e1685d054e59b470d17ea39830ea instead
# Created version '5' of model 'nyc-taxi-model'.

# %%
from mlflow import MlflowClient

client = MlflowClient(tracking_uri="sqlite:///mlflow.db")

# %%
client.create_registered_model(name="nyc-taxi-model-client")
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# File c:\Users\canal\miniconda3\Lib\site-packages\sqlalchemy\engine\base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File c:\Users\canal\miniconda3\Lib\site-packages\sqlalchemy\engine\default.py:951, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     950 def do_execute(self, cursor, statement, parameters, context=None):
# --> 951     cursor.execute(statement, parameters)
#
# IntegrityError: UNIQUE constraint failed: registered_models.name
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# File c:\Users\canal\miniconda3\Lib\site-packages\mlflow\store\model_registry\sqlalchemy_store.py:205, in SqlAlchemyStore.create_registered_model(self, name, tags, description, deployment_job_id)
#     204 session.add(registered_model)
# --> 205 session.flush()
#     206 return registered_model.to_mlflow_entity()
#
# File c:\Users\canal\miniconda3\Lib\site-packages\sqlalchemy\orm\session.py:4331, in Session.flush(self, objects)
#    4330     self._flushing = True
# -> 4331     self._flush(objects)
#    4332 finally:
#
# File c:\Users\canal\miniconda3\Lib\site-packages\sqlalchemy\orm\session.py:4466, in Session._flush(self, objects)
#    4465 except:
# -> 4466     with util.safe_reraise():
#    4467         transaction.rollback(_capture_exception=True)
#
# File c:\Users\canal\miniconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py:224, in safe_reraise.__exit__(self, type_, value, traceback)
#     223     self._exc_info = None  # remove potential circular references
# --> 224     raise exc_value.with_traceback(exc_tb)
#     225 else:
#
# File c:\Users\canal\miniconda3\Lib\site-packages\sqlalchemy\orm\session.py:4427, in Session._flush(self, objects)
#    4426 try:
# -> 4427     flush_context.execute()
#    4428 finally:
#
# File c:\Users\canal\miniconda3\Lib\site-packages\sqlalchemy\orm\unitofwork.py:466, in UOWTransaction.execute(self)
#     465 for rec in topological.sort(self.dependencies, postsort_actions):
# --> 466     rec.execute(self)
#
# File c:\Users\canal\miniconda3\Lib\site-packages\sqlalchemy\orm\unitofwork.py:642, in SaveUpdateAll.execute(self, uow)
#     640 @util.preload_module("sqlalchemy.orm.persistence")
#     641 def execute(self, uow):
# --> 642     util.preloaded.orm_persistence.save_obj(
#     643         self.mapper,
#     644         uow.states_for_mapper_hierarchy(self.mapper, False, False),
#     645         uow,
#     646     )
#
# File c:\Users\canal\miniconda3\Lib\site-packages\sqlalchemy\orm\persistence.py:93, in save_obj(base_mapper, states, uowtransaction, single)
#      85     _emit_update_statements(
#      86         base_mapper,
#      87         uowtransaction,
#    (...)     90         update,
#      91     )
# ---> 93     _emit_insert_statements(
#      94         base_mapper,
#      95         uowtransaction,
#      96         mapper,
#      97         table,
#      98         insert,
#      99     )
#     101 _finalize_insert_update_commands(
#     102     base_mapper,
#     103     uowtransaction,
#    (...)    119     ),
#     120 )
#
# File c:\Users\canal\miniconda3\Lib\site-packages\sqlalchemy\orm\persistence.py:1048, in _emit_insert_statements(base_mapper, uowtransaction, mapper, table, insert, bookkeeping, use_orm_insert_stmt, execution_options)
#    1046 multiparams = [rec[2] for rec in records]
# -> 1048 result = connection.execute(
#    1049     statement, multiparams, execution_options=execution_options
#    1050 )
#    1051 if bookkeeping:
#
# File c:\Users\canal\miniconda3\Lib\site-packages\sqlalchemy\engine\base.py:1419, in Connection.execute(self, statement, parameters, execution_options)
#    1418 else:
# -> 1419     return meth(
#    1420         self,
#    1421         distilled_parameters,
#    1422         execution_options or NO_OPTIONS,
#    1423     )
#
# File c:\Users\canal\miniconda3\Lib\site-packages\sqlalchemy\sql\elements.py:526, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     525         assert isinstance(self, Executable)
# --> 526     return connection._execute_clauseelement(
#     527         self, distilled_params, execution_options
#     528     )
#     529 else:
#
# File c:\Users\canal\miniconda3\Lib\site-packages\sqlalchemy\engine\base.py:1641, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1633 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1634     dialect=dialect,
#    1635     compiled_cache=compiled_cache,
#    (...)   1639     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1640 )
# -> 1641 ret = self._execute_context(
#    1642     dialect,
#    1643     dialect.execution_ctx_cls._init_compiled,
#    1644     compiled_sql,
#    1645     distilled_parameters,
#    1646     execution_options,
#    1647     compiled_sql,
#    1648     distilled_parameters,
#    1649     elem,
#    1650     extracted_params,
#    1651     cache_hit=cache_hit,
#    1652 )
#    1653 if has_events:
#
# File c:\Users\canal\miniconda3\Lib\site-packages\sqlalchemy\engine\base.py:1846, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1845 else:
# -> 1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File c:\Users\canal\miniconda3\Lib\site-packages\sqlalchemy\engine\base.py:1986, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1985 except BaseException as e:
# -> 1986     self._handle_dbapi_exception(
#    1987         e, str_statement, effective_parameters, cursor, context
#    1988     )
#    1990 return result
#
# File c:\Users\canal\miniconda3\Lib\site-packages\sqlalchemy\engine\base.py:2355, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2354     assert sqlalchemy_exception is not None
# -> 2355     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2356 else:
#
# File c:\Users\canal\miniconda3\Lib\site-packages\sqlalchemy\engine\base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File c:\Users\canal\miniconda3\Lib\site-packages\sqlalchemy\engine\default.py:951, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     950 def do_execute(self, cursor, statement, parameters, context=None):
# --> 951     cursor.execute(statement, parameters)
#
# IntegrityError: (sqlite3.IntegrityError) UNIQUE constraint failed: registered_models.name
# [SQL: INSERT INTO registered_models (name, creation_time, last_updated_time, description) VALUES (?, ?, ?, ?)]
# [parameters: ('nyc-taxi-model-client', 1761700081392, 1761700081392, None)]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
#
# During handling of the above exception, another exception occurred:
#
# MlflowException                           Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 client.create_registered_model(name="nyc-taxi-model-client")
#
# File c:\Users\canal\miniconda3\Lib\site-packages\mlflow\tracking\client.py:3724, in MlflowClient.create_registered_model(self, name, tags, description, deployment_job_id)
#    3721 if has_prompt_tag(tags):
#    3722     raise MlflowException.invalid_parameter_value("Prompts cannot be registered as models.")
# -> 3724 return self._get_registry_client().create_registered_model(
#    3725     name, tags, description, deployment_job_id
#    3726 )
#
# File c:\Users\canal\miniconda3\Lib\site-packages\mlflow\telemetry\track.py:30, in record_usage_event.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      28 start_time = time.time()
#      29 try:
# ---> 30     result = func(*args, **kwargs)
#      31     return result  # noqa: RET504
#      32 except Exception:
#
# File c:\Users\canal\miniconda3\Lib\site-packages\mlflow\tracking\_model_registry\client.py:95, in ModelRegistryClient.create_registered_model(self, name, tags, description, deployment_job_id)
#      93 tags = tags if tags else {}
#      94 tags = [RegisteredModelTag(key, str(value)) for key, value in tags.items()]
# ---> 95 return self.store.create_registered_model(name, tags, description, deployment_job_id)
#
# File c:\Users\canal\miniconda3\Lib\site-packages\mlflow\store\model_registry\sqlalchemy_store.py:209, in SqlAlchemyStore.create_registered_model(self, name, tags, description, deployment_job_id)
#     207 except sqlalchemy.exc.IntegrityError:
#     208     existing_model = self.get_registered_model(name)
# --> 209     handle_resource_already_exist_error(
#     210         name, has_prompt_tag(existing_model._tags), has_prompt_tag(tags)
#     211     )
#
# File c:\Users\canal\miniconda3\Lib\site-packages\mlflow\prompt\registry_utils.py:219, in handle_resource_already_exist_error(name, is_existing_entity_prompt, is_new_entity_prompt)
#     211 if old_entity != new_entity:
#     212     raise MlflowException(
#     213         f"Tried to create a {new_entity.lower()} with name {name!r}, but the name is "
#     214         f"already taken by a {old_entity.lower()}. MLflow does not allow creating a "
#     215         "model and a prompt with the same name.",
#     216         RESOURCE_ALREADY_EXISTS,
#     217     )
# --> 219 raise MlflowException(
#     220     f"{new_entity} (name={name}) already exists.",
#     221     RESOURCE_ALREADY_EXISTS,
#     222 )
#
# MlflowException: Registered Model (name=nyc-taxi-model-client) already exists.

# %%
# create "champion" alias for version 1 of model "example-model"
client.set_registered_model_alias(
    name="nyc-taxi-model", 
    alias="champion",
    version=1
)

# set the "challenger" alias to version 2
client.set_registered_model_alias(
    name="nyc-taxi-model", 
    alias="challenger",
    version=2
)

# %%
client.update_model_version(
    name="nyc-taxi-model",
    version=1,
    description="This model version is a scikit-learn XGBoost.",
)
# Out:
# <ModelVersion: aliases=['champion'], creation_timestamp=1761697739222, current_stage='None', deployment_job_state=None, description='This model version is a scikit-learn XGBoost.', last_updated_timestamp=1761700132607, metrics=None, model_id=None, name='nyc-taxi-model', params=None, run_id='e57df4c2ac064aaab0395bf2041639fe', run_link=None, source='models:/m-8e8158bacc2b4653aca901ba125278c2', status='READY', status_message=None, tags={}, user_id=None, version=1>

# %%
import mlflow
import mlflow.sklearn

with mlflow.start_run():
    mlflow.sklearn.log_model(
        sk_model=model,
        artifact_path="model",
        registered_model_name="nyc-taxi-model"
    )
# Out:
# 2025/10/28 19:09:15 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/10/28 19:09:15 WARNING mlflow.sklearn: Model was missing function: predict. Not logging python_function flavor!
# 2025/10/28 19:09:18 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Registered model 'nyc-taxi-model' already exists. Creating a new version of this model...
# Created version '6' of model 'nyc-taxi-model'.

# %%
import mlflow.pyfunc

model_name = "nyc-taxi-model"
model_version = 1

model_uri = f"models:/{model_name}/{model_version}"

model = mlflow.pyfunc.load_model(
    model_uri=model_uri,
)

model.predict(X_val)
# Out:
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[35], line 8
#       4 model_version = 1
#       6 model_uri = f"models:/{model_name}/{model_version}"
# ----> 8 model = mlflow.pyfunc.load_model(
#       9     model_uri=model_uri,
#      10 )
#      12 model.predict(X_val)
#
# File c:\Users\canal\miniconda3\Lib\site-packages\mlflow\tracing\provider.py:567, in trace_disabled.<locals>.wrapper(*args, **kwargs)
#     565 try:
#     566     is_func_called = True
# --> 567     result = f(*args, **kwargs)
#     568 finally:
#     569     enable()
#
# File c:\Users\canal\miniconda3\Lib\site-packages\mlflow\pyfunc\__init__.py:1151, in load_model(model_uri, suppress_warnings, dst_path, model_config)
#    1149 conf = model_meta.flavors.get(FLAVOR_NAME)
#    1150 if conf is None:
# -> 1151     raise MlflowException(
#    1152         f'Model does not have the "{FLAVOR_NAME}" flavor',
#    1153         RESOURCE_DOES_NOT_EXIST,
#    1154     )
#    1155 model_py_version = conf.get(PY_VERSION)
#    1156 if not suppress_warnings:
#
# MlflowException: Model does not have the "python_function" flavor

# %%
import mlflow.pyfunc

model_name = "nyc-taxi-model"
alias = "champion"

model_uri = f"models:/{model_name}@{alias}"

champion_version = mlflow.pyfunc.load_model(
    model_uri=model_uri
)

champion_version.predict(X_val)
# Out:
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[36], line 8
#       4 alias = "champion"
#       6 model_uri = f"models:/{model_name}@{alias}"
# ----> 8 champion_version = mlflow.pyfunc.load_model(
#       9     model_uri=model_uri
#      10 )
#      12 champion_version.predict(X_val)
#
# File c:\Users\canal\miniconda3\Lib\site-packages\mlflow\tracing\provider.py:567, in trace_disabled.<locals>.wrapper(*args, **kwargs)
#     565 try:
#     566     is_func_called = True
# --> 567     result = f(*args, **kwargs)
#     568 finally:
#     569     enable()
#
# File c:\Users\canal\miniconda3\Lib\site-packages\mlflow\pyfunc\__init__.py:1151, in load_model(model_uri, suppress_warnings, dst_path, model_config)
#    1149 conf = model_meta.flavors.get(FLAVOR_NAME)
#    1150 if conf is None:
# -> 1151     raise MlflowException(
#    1152         f'Model does not have the "{FLAVOR_NAME}" flavor',
#    1153         RESOURCE_DOES_NOT_EXIST,
#    1154     )
#    1155 model_py_version = conf.get(PY_VERSION)
#    1156 if not suppress_warnings:
#
# MlflowException: Model does not have the "python_function" flavor

# %%
def read_dataframe(filename):
    df = pd.read_parquet(filename)

    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)

    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    
    return df


def preprocess(df, dv):
    df['PU_DO'] = df['PULocationID'] + '_' + df['DOLocationID']
    categorical = ['PU_DO']
    numerical = ['trip_distance']
    train_dicts = df[categorical + numerical].to_dict(orient='records')
    return dv.transform(train_dicts)


def test_model(name, alias, X_test, y_test):
    model = mlflow.pyfunc.load_model(f"models:/{name}@{alias}")
    y_pred = model.predict(X_test)
    return {"rmse": root_mean_squared_error(y_test, y_pred)}

# %%
df = read_dataframe("../data/green_tripdata_2025-03.parquet")

# %%
run_id = input("Ingrese el run_id")

client.download_artifacts(
    run_id=run_id, 
    path='preprocessor', 
    dst_path='.'
)
# Out:
# Downloading artifacts:   0%|          | 0/1 [00:00<?, ?it/s]
# 'c:\\Users\\canal\\Documents\\Semestre 7\\Proyecto de Ciencia de Datos\\nyc-predictions\\nyc-taxi-predictions-2025-2\\notebooks\\preprocessor'

# %%
with open("preprocessor/preprocessor.b", "rb") as f_in:
    dv = pickle.load(f_in)

# %%
X_test = preprocess(df, dv)

# %%
target = "duration"
y_test = df[target].values

# %%
# %time test_model(name="nyc-taxi-model", alias="champion", X_test=X_test, y_test=y_test)
# Out:
# CPU times: total: 0 ns
# Wall time: 11.4 μs
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 get_ipython().run_line_magic('time', 'test_model(name="nyc-taxi-model", alias="champion", X_test=X_test, y_test=y_test)')
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\interactiveshell.py:2504, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2502     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2503 with self.builtin_trap:
# -> 2504     result = fn(*args, **kwargs)
#    2506 # The code below prevents the output from being displayed
#    2507 # when using magics with decorator @output_can_be_silenced
#    2508 # when the last Python token in the expression is a ';'.
#    2509 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\magics\execution.py:1452, in ExecutionMagics.time(self, line, cell, local_ns)
#    1450 if interrupt_occured:
#    1451     if exit_on_interrupt and captured_exception:
# -> 1452         raise captured_exception
#    1453     return
#    1454 return out
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\magics\execution.py:1402, in ExecutionMagics.time(self, line, cell, local_ns)
#    1400 st = clock2()
#    1401 try:
# -> 1402     out = eval(code, glob, local_ns)
#    1403 except KeyboardInterrupt as e:
#    1404     captured_exception = e
#
# File <timed eval>:1
#
# NameError: name 'champion' is not defined

# %%
# %time test_model(name=model_name, alias="challenger", X_test=X_test, y_test=y_test)
# Out:
# CPU times: total: 0 ns
# Wall time: 8.82 μs
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 get_ipython().run_line_magic('time', 'test_model(name=model_name, alias="challenger", X_test=X_test, y_test=y_test)')
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\interactiveshell.py:2504, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2502     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2503 with self.builtin_trap:
# -> 2504     result = fn(*args, **kwargs)
#    2506 # The code below prevents the output from being displayed
#    2507 # when using magics with decorator @output_can_be_silenced
#    2508 # when the last Python token in the expression is a ';'.
#    2509 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\magics\execution.py:1452, in ExecutionMagics.time(self, line, cell, local_ns)
#    1450 if interrupt_occured:
#    1451     if exit_on_interrupt and captured_exception:
# -> 1452         raise captured_exception
#    1453     return
#    1454 return out
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\magics\execution.py:1402, in ExecutionMagics.time(self, line, cell, local_ns)
#    1400 st = clock2()
#    1401 try:
# -> 1402     out = eval(code, glob, local_ns)
#    1403 except KeyboardInterrupt as e:
#    1404     captured_exception = e
#
# File <timed eval>:1
#
# NameError: name 'challenger' is not defined

# %%
client.set_registered_model_alias(
    name="nyc-taxi-model", 
    alias="champion",
    version=100
)
# Out:
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 client.set_registered_model_alias(
#       2     name="nyc-taxi-model",
#       3     alias="champion",
#       4     version=100
#       5 )
#
# File c:\Users\canal\miniconda3\Lib\site-packages\mlflow\tracking\client.py:5252, in MlflowClient.set_registered_model_alias(self, name, alias, version)
#    5250 _validate_model_version(version)
#    5251 self._raise_if_prompt(name)
# -> 5252 self._get_registry_client().set_registered_model_alias(name, alias, version)
#
# File c:\Users\canal\miniconda3\Lib\site-packages\mlflow\tracking\_model_registry\client.py:449, in ModelRegistryClient.set_registered_model_alias(self, name, alias, version)
#     438 def set_registered_model_alias(self, name, alias, version):
#     439     """Set a registered model alias pointing to a model version.
#     440
#     441     Args:
#    (...)    447         None
#     448     """
# --> 449     self.store.set_registered_model_alias(name, alias, version)
#
# File c:\Users\canal\miniconda3\Lib\site-packages\mlflow\store\model_registry\sqlalchemy_store.py:1250, in SqlAlchemyStore.set_registered_model_alias(self, name, alias, version)
#    1247 _validate_model_version(version)
#    1248 with self.ManagedSessionMaker() as session:
#    1249     # check if model version exists
# -> 1250     self._get_sql_model_version(session, name, version)
#    1251     session.merge(SqlRegisteredModelAlias(name=name, alias=alias, version=version))
#
# File c:\Users\canal\miniconda3\Lib\site-packages\mlflow\store\model_registry\sqlalchemy_store.py:875, in SqlAlchemyStore._get_sql_model_version(cls, session, name, version, eager)
#     869 query_options = cls._get_eager_model_version_query_options() if eager else []
#     870 conditions = [
#     871     SqlModelVersion.name == name,
#     872     SqlModelVersion.version == version,
#     873     SqlModelVersion.current_stage != STAGE_DELETED_INTERNAL,
#     874 ]
# --> 875 return cls._get_model_version_from_db(session, name, version, conditions, query_options)
#
# File c:\Users\canal\miniconda3\Lib\site-packages\mlflow\store\model_registry\sqlalchemy_store.py:846, in SqlAlchemyStore._get_model_version_from_db(cls, session, name, version, conditions, query_options)
#     843 versions = session.query(SqlModelVersion).options(*query_options).filter(*conditions).all()
#     845 if len(versions) == 0:
# --> 846     raise MlflowException(
#     847         f"Model Version (name={name}, version={version}) not found",
#     848         RESOURCE_DOES_NOT_EXIST,
#     849     )
#     850 if len(versions) > 1:
#     851     raise MlflowException(
#     852         f"Expected only 1 model version with (name={name}, version={version}). "
#     853         f"Found {len(versions)}.",
#     854         INVALID_STATE,
#     855     )
#
# MlflowException: Model Version (name=nyc-taxi-model, version=100) not found
